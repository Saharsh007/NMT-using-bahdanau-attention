# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import GRU
import numpy as  np
from numpy import array
import tensorflow as tf
import numpy
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## output of GRU for one timestep given return sequences and return state is true

# %%
# define model
inputs1 = Input(shape=(1, 1))
lstm1, state_h = GRU(1, return_sequences=True, return_state=True)(inputs1)
model = Model(inputs=inputs1, outputs=[lstm1, state_h])
# define input data
data = array([0.1]).reshape((1,1,1))
# make and show prediction
print(model.predict(data))
# Out:
# [array([[[-0.04497656]]], dtype=float32), array([[-0.04497656]], dtype=float32)]

# %%
output = model.predict(data)

# %%
output1 = output[0]
output2 = output[1]

# %%
print(output1)
print(output2)
# Out:
# [[[-0.04497656]]]
# [[-0.04497656]]

# %% [markdown]
# ### notice output 1 is 3d array that is it's shape is (batch_size,time_steps,units_in_hidden_state)
# units_in_hidden_state = 1

# %% [markdown]
# ## what is the below code doing

# %%
'''
In the snippet below, there is a single floating point value per example for
`y_true` and `# classes` floating pointing values per example for `y_pred`.
The shape of `y_true` is `[batch_size]` and the shape of `y_pred` is
`[batch_size, num_classes]`.
'''
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    # tf.math.logical - Returns the truth value of NOT x element-wise.
    # tf.math.equal - Returns the truth value of (x == y) element-wise.
    # Since we padded zeros into the sequences, let’s not take those zeros into account when computing the loss:
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    # loss as defined in the image above
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
real = tf.convert_to_tensor([1,0,2,0,0,2,3])
pred = tf.convert_to_tensor([8,7,1,0,4,1,3])

loss_function(real,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8ae47f2970d2> in <module>
#       2 pred = tf.convert_to_tensor([8,7,1,0,4,1,3])
#       3
# ----> 4 loss_function(real,pred)
#
# <ipython-input-3-cb9310175758> in loss_function(real, pred)
#       8     mask = tf.math.logical_not(tf.math.equal(real, 0))
#       9     # loss as defined in the image above
# ---> 10     loss_ = loss_object(real, pred)
#      11
#      12     mask = tf.cast(mask, dtype=loss_.dtype)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/losses.py in __call__(self, y_true, y_pred, sample_weight)
#     121         y_true, y_pred, sample_weight)
#     122     with K.name_scope(scope_name or self.__class__.__name__), graph_ctx:
# --> 123       losses = self.call(y_true, y_pred)
#     124       return losses_utils.compute_weighted_loss(
#     125           losses, sample_weight, reduction=self._get_reduction())
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/losses.py in call(self, y_true, y_pred)
#     213       Loss values per sample.
#     214     """
# --> 215     return self.fn(y_true, y_pred, **self._fn_kwargs)
#     216
#     217   def get_config(self):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/losses.py in sparse_categorical_crossentropy(y_true, y_pred, from_logits, axis)
#     951 def sparse_categorical_crossentropy(y_true, y_pred, from_logits=False, axis=-1):
#     952   return K.sparse_categorical_crossentropy(
# --> 953       y_true, y_pred, from_logits=from_logits, axis=axis)
#     954
#     955
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in sparse_categorical_crossentropy(target, output, from_logits, axis)
#    4203   logits = array_ops.reshape(output, [-1, int(output_shape[-1])])
#    4204   res = nn.sparse_softmax_cross_entropy_with_logits(
# -> 4205       labels=targets, logits=logits)
#    4206   if len(output_shape) >= 3:
#    4207     # If our output includes timesteps or spatial dimensions we need to reshape
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py in sparse_softmax_cross_entropy_with_logits(_sentinel, labels, logits, name)
#    3336                        "should equal the shape of logits except for the last "
#    3337                        "dimension (received %s)." % (labels_static_shape,
# -> 3338                                                      logits.get_shape()))
#    3339     # Check if no reshapes are required.
#    3340     if logits.get_shape().ndims == 2:
#
# ValueError: Shape mismatch: The shape of labels (received (7,)) should equal the shape of logits except for the last dimension (received (1, 7)).
